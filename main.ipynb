# %% [markdown]
# ### 호재혁씨의 병문안으로 인한 감동으로 인한 캡스톤 도장깨기 주석도 좀 달아놓게여

# %%
from numpy.ma.core import outer

# 1. get model
from model import UNet
import torch
model = UNet()
rand_data = torch.randn(size=(4, 3, 224, 224)) # -> B, C, W, H
out = model(rand_data) # -> B, 1, W, H
print(out)
print(out.shape)
# Out:
# /media/unsi/media/code/forjh_caps/model.py:108: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   output1 = nn.functional.upsample(input1, output2.size()[2:], mode="bilinear")
# tensor([[[[-0.1919, -0.0788, -0.1731,  ..., -0.1000, -0.0787, -0.1638],
#           [ 0.0345,  0.0711, -0.0234,  ..., -0.0656, -0.0827, -0.0721],
#           [-0.1235, -0.0590, -0.1627,  ..., -0.2580, -0.1372, -0.1969],
#           ...,
#           [-0.1065, -0.0327, -0.1072,  ..., -0.0277,  0.0255, -0.0631],
#           [-0.1196, -0.1442, -0.1595,  ..., -0.0089, -0.0995,  0.0019],
#           [-0.0745, -0.0819, -0.1743,  ..., -0.0607, -0.0659, -0.0665]]],
#
#
#         [[[-0.0368, -0.1015, -0.1099,  ..., -0.1292, -0.0974, -0.0350],
#           [-0.0504,  0.0086, -0.0221,  ..., -0.1261, -0.0424, -0.0184],
#           [-0.0860, -0.0385, -0.0858,  ..., -0.1223, -0.0422,  0.0060],
#           ...,
#           [-0.1356, -0.0769, -0.0737,  ..., -0.0604, -0.1301, -0.1000],
#           [-0.1465, -0.0260, -0.0908,  ..., -0.1065, -0.0461, -0.0566],
#           [-0.1643,  0.0005, -0.1607,  ..., -0.0629, -0.0558, -0.0915]]],
#
#
#         [[[-0.0531, -0.0775, -0.1091,  ..., -0.2409, -0.0346, -0.1628],
#           [-0.1566, -0.0547, -0.0924,  ..., -0.0145,  0.0345,  0.0444],
#           [-0.0941, -0.1310, -0.0782,  ..., -0.1352, -0.0878, -0.1549],
#           ...,
#           [-0.0438, -0.0742, -0.0793,  ..., -0.1150, -0.1501, -0.0377],
#           [-0.0730,  0.0137, -0.0950,  ..., -0.1903, -0.0989, -0.1082],
#           [-0.0217, -0.0910, -0.1038,  ..., -0.0941, -0.1349, -0.0342]]],
#
#
#         [[[-0.0768, -0.1095, -0.0875,  ..., -0.0436,  0.0046, -0.0678],
#           [-0.1056, -0.0250, -0.1302,  ..., -0.1759, -0.1337, -0.0631],
#           [-0.0434, -0.1353, -0.1014,  ..., -0.0717, -0.0119, -0.1185],
#           ...,
#           [-0.0770, -0.0548, -0.1622,  ..., -0.0473, -0.0906, -0.1272],
#           [-0.0638, -0.0671, -0.0308,  ..., -0.1426, -0.0157, -0.0444],
#           [ 0.0433, -0.0502, -0.0686,  ..., -0.0126, -0.0769, -0.0468]]]],
#        grad_fn=<UpsampleBilinear2DBackward0>)
# torch.Size([4, 1, 224, 224])
# /media/unsi/media/code/forjh_caps/model.py:174: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   final = nn.functional.upsample(

# %%
#데이터셋 읽어오기, 너가 데이터 받아서 이미지 path만 split_xml_path에 인자로 넣으면 됨  ex -> split_xml_path('jh/~~~')
from utils import *
(X_train_path, Y_train_path), (X_test_path, Y_test_path), (X_val_path, Y_val_path), (X_sample_path, Y_sample_path) = split_xml_path()
len(X_train_path)
# Out:
# 총 데이터 개수: 2913
# 2490

# %%
#dataset test
from CustomDataSet import Dataset
(X_train_path, Y_train_path), (X_test_path, Y_test_path), (X_val_path, Y_val_path), (X_sample_path, Y_sample_path) = split_xml_path()
sample_ds = Dataset(X_train_path, Y_train_path)
x, y = next(iter(sample_ds))
from matplotlib import pyplot as plt
plt.imshow(x.permute(1,2,0).to('cpu').numpy())
plt.show()
# Out:
# 총 데이터 개수: 2913
# Total loaded samples: 2490
